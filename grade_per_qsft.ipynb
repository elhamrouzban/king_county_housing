# %%
import warnings

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


warnings.filterwarnings("ignore")

plt.rcParams.update(
    {"figure.figsize": (8, 5), "axes.facecolor": "white", "axes.edgecolor": "black"}
)
plt.rcParams["figure.facecolor"] = "w"
pd.plotting.register_matplotlib_converters()
pd.set_option("display.float_format", lambda x: "%.3f" % x)

# %%
df = pd.read_csv(
    "data/king_county_housing_clean.csv",
    parse_dates=["date"]
)

# %%
df.head()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  7129300520     3.000      1.000     1180.000  5650.000   1.000           0
# 1  6414100192     3.000      2.250     2570.000  7242.000   2.000           0
# 2  5631500400     2.000      1.000      770.000 10000.000   1.000           0
# 3  2487200875     4.000      3.000     1960.000  5000.000   1.000           0
# 4  1954400510     3.000      2.000     1680.000  8080.000   1.000           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...          0.000      1955             0
# 1     0          3      7  ...        400.000      1951          1991
# 2     0          3      6  ...          0.000      1933             0
# 3     0          5      7  ...        910.000      1965             0
# 4     0          3      8  ...          0.000      1987             0
#
#    zipcode    lat     long  sqft_living15  sqft_lot15       date      price
# 0    98178 47.511 -122.257       1340.000    5650.000 2014-10-13 221900.000
# 1    98125 47.721 -122.319       1690.000    7639.000 2014-12-09 538000.000
# 2    98028 47.738 -122.233       2720.000    8062.000 2015-02-25 180000.000
# 3    98136 47.521 -122.393       1360.000    5000.000 2014-12-09 604000.000
# 4    98074 47.617 -122.045       1800.000    7503.000 2015-02-18 510000.000
#
# [5 rows x 21 columns]

# %%
df["grade"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 21597 entries, 0 to 21596
# Series name: grade
# Non-Null Count  Dtype
# --------------  -----
# 21597 non-null  int64
# dtypes: int64(1)
# memory usage: 168.9 KB

# %%
df["price_per_sqft"] = df["price"] / df["sqft_living"]

# %%
df["zipcode"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 21597 entries, 0 to 21596
# Series name: zipcode
# Non-Null Count  Dtype
# --------------  -----
# 21597 non-null  int64
# dtypes: int64(1)
# memory usage: 168.9 KB

# %%
grade_location = (
    df.groupby(["grade", "zipcode"])["price_per_sqft"]
      .mean()
      .reset_index()
)

grade_location.head()
# Out:
#    grade  zipcode  price_per_sqft
# 0      3    98022         503.846
# 1      4    98010         634.615
# 2      4    98014         350.630
# 3      4    98023         176.471
# 4      4    98024         266.234
